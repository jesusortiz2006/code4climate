# %%
from matplotlib.colors import is_color_like
from IPython.core.magics.namespace import read_py_file
"""
The code will take a day that is prompted from the user
and display a graph that analyzes the Air Quality Index
for that day.
"""
"""
----------------------------------------------------------------------------
"""
"""To break down step by step:

1. Code will ask user for a given day to analyze Air Quality Data - Completed
2. Code will pull out the csv file for the day prompted by the user - Completed

3. Code will run some calculations; It will find the average concentrations for
particulate matter for the day, then  find the Air Quality Index for the prompted day,
then plot the variations hour-by-hour basis for that day. -
4. Code will print out a graph to demonstrate this information -
---------------------------------------------------------------------------
"""
"""

Equations:

average_particulate_matter = ug/m^3

Air_Quality_Index = Ip = Ihi - Ilo / BPhi - BPlo (Cp - BPlo) + Ilo

---------------------------------------------------------------------------
"""
#imports here
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np#imports for graph and equations
sunIhi = 23.448275862068964
#code here
def code(): #this one function will run the entire code
  day = input("What day would you like to view? ") #day helps the code know what day the user would like to analyze
  print("Here is the Air Quality for " + day + ":")
  if day == "Sunday" or "sunday": #if conditions for Sun - Sat for picking correct file / calculations
    data = pd.read_csv('clean_20211224.csv') #data will retract the csv file for reference
    Cp = np.mean(data['PM2.5'])
    if Cp == range(0.0, 12.0):
      Ihi = 50
      Ilo = 0
    if Cp == range(12.1, 35.4):
      Ihi = 100
      Ilo = 51
    if Cp == range(35.5, 55.4):
      Ihi = 150
      Ilo = 101
    if Cp == range(55.5, 150.4)^3:
      Ihi = 200
      Ilo = 151
    if Cp == range(150.5 - 250.4)^3:
      Ihi = 300
      Ilo = 201
    if Cp == range(250.5, 350.4)^3:
      Ihi = 400
      Ilo = 301
    if Cp == range(350.5, 500.4)^3:
      Ihi = 500
      Ilo = 401
    average_concentrations_particulate_matter = (Ihi-Ilo)/(BPHi - BPLo)*(Cp - BPLo) + Ilo
    AQI = average_concentrations_particulate_matter
    """
    plt.plot("AQI") #Opens a new graph and plots the information, hour-by-hour
    """







"""
  elif day == "Monday" or "monday":
    data = pd.read_csv('clean_')
    average_particulate_matter = 1
    #Calculates the Air Quality Index
    plt.plot("AQI")
    #Opens a new graph and plots the information, hour-by-hour

  elif day == "Tuesday" or "tuesday":
    data = pd.read_csv('clean_')
    average_particulate_matter = 1
    #Calculates the Air Quality Index
    plt.plot("AQI")
    #Opens a new graph and plots the information, hour-by-hour

  elif day == "Wednesday" or "wednesday":
      data = pd.read_csv('clean_')
      average_particulate_matter = 1
      #Calculates the Air Quality Index
      plt.plot("AQI")
      #Opens a new graph and plots the information, hour-by-hour

  elif day == "Thursday" or "thursday":
      data = pd.read_csv('clean_')
      average_particulate_matter = 1
      #Calculates the Air Quality Index
      plt.plot("AQI")
      #Opens a new graph and plots the information, hour-by-hour

  elif day == "Friday" or "friday":
      data = pd.read_csv('clean_')
      average_particulate_matter = 1
      #Calculates the Air Quality Index
      plt.plot("AQI")
      #Opens a new graph and plots the information, hour-by-hour

  elif day == "Saturday" or "saturday":
      ata = pd.read_csv('clean_')
      average_particulate_matter = 1
      #Calculates the Air Quality Index
      plt.plot("AQI")
      #Opens a new graph and plots the information, hour-by-hour
  else:
    count = 0
    count = count + 1
    print("That is not a day of the week, please try entering your desired day again.")
    code()

  if count == 5:
    print("You are just messing with me :|")
"""
code()
# Out:
# What day would you like to view? sunday
# Here is the Air Quality for sunday:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-3ed44c2ec782> in <cell line: 107>()
#     105     print("You are just messing with me :|")
#     106 """
# --> 107 code()
#
# <ipython-input-59-3ed44c2ec782> in code()
#      40   if day == "Sunday" or "sunday": #if conditions for Sun - Sat for picking correct file / calculations
#      41     data = pd.read_csv('clean_20211224.csv') #data will retract the csv file for reference
# ---> 42     Cp = np.mean(read_file('clean_20211224.csv'))
#      43
#      44     average_concentrations_particulate_matter = (Ihi-Ilo)/(BPHi - BPLo)*(Cp - BPLo) + Ilo
#
# NameError: name 'read_file' is not defined
